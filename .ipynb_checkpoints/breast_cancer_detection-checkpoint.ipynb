# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn import metrics

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report,confusion_matrix,plot_confusion_matrix

# %%
df = pd.read_csv('breast_cancer_data.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
df.drop("Unnamed: 32", axis=1, inplace=True)

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.shape
# Out:
# (569, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# 357 absence of cancer cells and 212 presence
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %% [markdown]
# # Data Visualization

# %%
sns.countplot(x = "diagnosis", data = df)
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df_mean = df.iloc[:,2:12]

# %%
df_se = df.iloc[:,12:22]

# %%
df_worst = df.iloc[:,22:]

# %% [markdown]
# # Histograms

# %%
hist_mean = df_mean.hist(bins=10, figsize=(15, 10),grid=False)

# %%
hist_se = df_se.hist(bins=10, figsize=(15, 10),grid=False)

# %%
hist_worst = df_worst.hist(bins=10, figsize=(15, 10),grid=True)

# %%
pp_mean = sns.pairplot(df[df.columns[1:7]], hue = "diagnosis", plot_kws=dict(edgecolor="k", linewidth=0.5), diag_kind="kde", diag_kws=dict(shade=True))

# %%
sns.set(font_scale=0.6)
plt.title('Breast Cancer Feature Correlation')
cmap = sns.diverging_palette(260, 10, as_cmap=True)
sns.heatmap(df_mean.corr("spearman"), vmax=1.2, annot=True, square='square', cmap=cmap, fmt = '.0%', linewidths=2)
# Out:
# <AxesSubplot:title={'center':'Breast Cancer Feature Correlation'}>

# %%
sns.set(font_scale=0.6)
plt.title('Breast Cancer Feature Correlation')
cmap = sns.diverging_palette(260, 10, as_cmap=True)
sns.heatmap(df_se.corr("spearman"), vmax=1.2, annot=True, square='square', cmap=cmap, fmt = '.0%', linewidths=2)
# Out:
# <AxesSubplot:title={'center':'Breast Cancer Feature Correlation'}>

# %%
sns.set(font_scale=0.6)
plt.title('Breast Cancer Feature Correlation')
cmap = sns.diverging_palette(260, 10, as_cmap=True)
sns.heatmap(df_worst.corr("spearman"), vmax=1.2, annot=True, square='square', cmap=cmap, fmt = '.0%', linewidths=2)
# Out:
# <AxesSubplot:title={'center':'Breast Cancer Feature Correlation'}>

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr("spearman")
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features_mean = correlation(df_mean, 0.85)
corr_features_se = correlation(df_se, 0.85)
corr_features_worst = correlation(df_worst, 0.85)

display(corr_features_mean, corr_features_se, corr_features_worst)
# Out:
# {'area_mean', 'concave points_mean', 'concavity_mean', 'perimeter_mean'}
# {'area_se', 'concavity_se', 'perimeter_se'}
# {'area_worst', 'concave points_worst', 'concavity_worst', 'perimeter_worst'}

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df["diagnosis"] = encoder.fit_transform(df['diagnosis'])# encode malignant as 1 and benign as 0

# %% [markdown]
# # Feature Selection

# %%
display(corr_features_mean, corr_features_se, corr_features_worst)
coldrop=['fractal_dimension_mean',
 'texture_se',
 'smoothness_se',
 'symmetry_se',
 'fractal_dimension_se']

corr_features_mean = list(corr_features_mean)
corr_features_se = list(corr_features_se)
corr_features_worst = list(corr_features_worst)

list_drop = corr_features_mean + corr_features_se + corr_features_worst + coldrop
list_drop = list(set(list_drop))
list_drop.append("id")
list_drop
# Out:
# {'area_mean', 'concave points_mean', 'concavity_mean', 'perimeter_mean'}
# {'area_se', 'concavity_se', 'perimeter_se'}
# {'area_worst', 'concave points_worst', 'concavity_worst', 'perimeter_worst'}
# ['concave points_mean',
#  'perimeter_worst',
#  'concavity_worst',
#  'perimeter_mean',
#  'texture_se',
#  'fractal_dimension_mean',
#  'perimeter_se',
#  'area_worst',
#  'concave points_worst',
#  'smoothness_se',
#  'concavity_mean',
#  'concavity_se',
#  'area_se',
#  'symmetry_se',
#  'area_mean',
#  'fractal_dimension_se',
#  'id']

# %% [markdown]
# Dropping these features as some of them are highly correlated with independent features and hence acting as duplicates and some don't have any relation with target feature.

# %%
df.drop(list_drop, axis=1, inplace=True)
display(df.columns)
display(df.shape)
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'smoothness_mean',
#        'compactness_mean', 'symmetry_mean', 'radius_se', 'compactness_se',
#        'concave points_se', 'radius_worst', 'texture_worst',
#        'smoothness_worst', 'compactness_worst', 'symmetry_worst',
#        'fractal_dimension_worst'],
#       dtype='object')
# (569, 15)

# %%
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0          1        17.99         10.38          0.11840           0.27760
# 1          1        20.57         17.77          0.08474           0.07864
# 2          1        19.69         21.25          0.10960           0.15990
# 3          1        11.42         20.38          0.14250           0.28390
# 4          1        20.29         14.34          0.10030           0.13280
#
#    symmetry_mean  radius_se  compactness_se  concave points_se  radius_worst  \
# 0         0.2419     1.0950         0.04904            0.01587         25.38
# 1         0.1812     0.5435         0.01308            0.01340         24.99
# 2         0.2069     0.7456         0.04006            0.02058         23.57
# 3         0.2597     0.4956         0.07458            0.01867         14.91
# 4         0.1809     0.7572         0.02461            0.01885         22.54
#
# ...

# %%
# target feature separation
x = df.drop("diagnosis", axis=1)
y = df.diagnosis

# %% [markdown]
# # Train Test|split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)  #70 percent training 30 percent testing

# %%
y_train.shape, y_train[y_train==1].shape, y_train[y_train==0].shape
# Out:
# ((398,), (149,), (249,))

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_dt = DecisionTreeClassifier(max_depth=3)

# %%
model_dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
base_pred=model_dt.predict(x_test)

# %% [markdown]
# # Evaluation

# %%
confusion_matrix(y_test,base_pred)
# Out:
# array([[99,  9],
#        [ 8, 55]], dtype=int64)

# %%
plot_confusion_matrix(model_dt,x_test,y_test)
# Out:
# C:\Users\Ravi Yadav\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(classification_report(y_test,base_pred))
print("Accuracy:",metrics.accuracy_score(y_test, base_pred))
print("Precision:",metrics.precision_score(y_test, base_pred))
print("Recall:",metrics.recall_score(y_test, base_pred))
dt_train_acc = model_dt.score(x_train,y_train)
dt_test_accuracy = model_dt.score(x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92       108
#            1       0.86      0.87      0.87        63
#
#     accuracy                           0.90       171
#    macro avg       0.89      0.89      0.89       171
# weighted avg       0.90      0.90      0.90       171
#
# Accuracy: 0.9005847953216374
# Precision: 0.859375
# Recall: 0.873015873015873

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf=RandomForestClassifier()

# %%
model_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
base_pred_rf=model_rf.predict(x_test)

# %% [markdown]
# # Evaluation

# %%
confusion_matrix(y_test,base_pred_rf)
# Out:
# array([[105,   3],
#        [  5,  58]], dtype=int64)

# %%
plot_confusion_matrix(model_rf,x_test,y_test)
# Out:
# C:\Users\Ravi Yadav\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(classification_report(y_test,base_pred_rf))
print("Accuracy:",metrics.accuracy_score(y_test, base_pred_rf))
print("Precision:",metrics.precision_score(y_test, base_pred_rf))
print("Recall:",metrics.recall_score(y_test, base_pred_rf))
rf_train_acc = model_rf.score(x_train,y_train)
rf_test_accuracy = model_rf.score(x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       108
#            1       0.95      0.92      0.94        63
#
#     accuracy                           0.95       171
#    macro avg       0.95      0.95      0.95       171
# weighted avg       0.95      0.95      0.95       171
#
# Accuracy: 0.9532163742690059
# Precision: 0.9508196721311475
# Recall: 0.9206349206349206

# %% [markdown]
# # SVM Classifier

# %%
from sklearn.svm import SVC

# %%
model_svm = SVC()

# %%
model_svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
base_pred_svm=model_svm.predict(x_test)

# %% [markdown]
# # Evaluation

# %%
confusion_matrix(y_test,base_pred_svm)
# Out:
# array([[105,   3],
#        [ 11,  52]], dtype=int64)

# %%
plot_confusion_matrix(model_svm,x_test,y_test)
# Out:
# C:\Users\Ravi Yadav\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(classification_report(y_test,base_pred_svm))
print("Accuracy:",metrics.accuracy_score(y_test, base_pred_svm))
print("Precision:",metrics.precision_score(y_test, base_pred_svm))
print("Recall:",metrics.recall_score(y_test, base_pred_svm))
svm_train_acc = model_svm.score(x_train,y_train)
svm_test_accuracy = model_svm.score(x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       108
#            1       0.95      0.83      0.88        63
#
#     accuracy                           0.92       171
#    macro avg       0.93      0.90      0.91       171
# weighted avg       0.92      0.92      0.92       171
#
# Accuracy: 0.9181286549707602
# Precision: 0.9454545454545454
# Recall: 0.8253968253968254

# %% [markdown]
# # Comparison

# %%
def comp_model(model_list, model_train_acc_list, model_test_acc_list):
    data = {"Model Name": model_list, "Train Accuracy(%)": [i*100 for i in model_train_acc_list], "Test Accuracy(%)": [i*100 for i in model_test_acc_list]}
    Comparision = pd.DataFrame(data)
    return Comparision

# %%
model_list = ["Decision Tree Classifier", "SVM", "Random Forest Classifier"]
model_train_acc_list = [dt_train_acc, svm_train_acc, rf_train_acc]
model_test_acc_list = [dt_test_accuracy, svm_test_accuracy, rf_test_accuracy]
comp_model(model_list, model_train_acc_list, model_test_acc_list)
# Out:
#                  Model Name  Train Accuracy(%)  Test Accuracy(%)
# 0  Decision Tree Classifier          97.487437         90.058480
# 1                       SVM          92.964824         91.812865
# 2  Random Forest Classifier         100.000000         95.321637

# %% [markdown]
# # svm_model

# %%
#input data and transform into numpy array
in_data= np.asarray(tuple(map(float,input().rstrip().split(','))))

#reshape and scale the input array
in_data_re = in_data.reshape(1,-1)


#print the predicted output for input array
print("Breast Cancer Detected (Malignant)" if model_svm.predict(in_data_re) else "No Breast Cancer Detected (Benign)")

# %%
import pickle

# %%
filename = 'trained_model.sav'
pickle.dump(model_svm, open(filename, 'wb'))

# %%
# loading the saved model
loaded_model = pickle.load(open('trained_model.sav', 'rb'))

# %%
#input data and transform into numpy array
in_data= np.asarray(tuple(map(float,input().rstrip().split(','))))

#reshape and scale the input array
in_data_re = in_data.reshape(1,-1)


#print the predicted output for input array
print("Breast Cancer Detected (Malignant)" if loaded_model.predict(in_data_re) else "No Breast Cancer Detected (Benign)")
